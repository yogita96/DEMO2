# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread(r"E:\computer vision\1 Day wise Notes\images\q2.jpg")
img1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img1, cmap='gray')

# %%
des_list=[]

orb=cv2.ORB_create()

# %%
kp = orb.detect(img1,None)

# %%
kp, des = orb.compute(img, kp)

# %%
img3=cv2.drawKeypoints(img1, kp, None)
plt.imshow(img3)
